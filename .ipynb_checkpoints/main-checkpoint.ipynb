# %% [markdown]
# # Load in Data

# %%
# Load in dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from scipy.stats import pearsonr, spearmanr
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

# load in data
data = pd.read_csv("~/Documents/Git/kaggle_housing_prices_advanced_regression_techniques/train.csv")

data.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# # Examine Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %% [markdown]
# # Split data by categorical and numeric data

# %%
# group features by data type
numeric_data = data.select_dtypes(include='number').copy()
categorical_data = data.select_dtypes(include='object').copy()

# %% [markdown]
# # Examine number of NaN values in data

# %%
# examine nan values in categorical data
total_count = numeric_data.count() + numeric_data.isna().sum()
numeric_data.isna().sum() / total_count

# -or-

numeric_nan_pct = numeric_data.isna().mean()
# only display columns with a nan% above zero
print(numeric_nan_pct[numeric_nan_pct > 0])
# Out:
# LotFrontage    0.177397
# MasVnrArea     0.005479
# GarageYrBlt    0.055479
# dtype: float64

# %%
# examine nan values in categorical data
total_count = categorical_data.count() + categorical_data.isna().sum()
categorical_data.isna().sum() / total_count

# -or-

categorical_nan_pct = categorical_data.isna().mean()
# only display columns with a nan% above zero
print(categorical_nan_pct[categorical_nan_pct > 0])
# Out:
# Alley           0.937671
# MasVnrType      0.005479
# BsmtQual        0.025342
# BsmtCond        0.025342
# BsmtExposure    0.026027
# BsmtFinType1    0.025342
# BsmtFinType2    0.026027
# Electrical      0.000685
# FireplaceQu     0.472603
# GarageType      0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# GarageCond      0.055479
# PoolQC          0.995205
# Fence           0.807534
# MiscFeature     0.963014
# dtype: float64

# %% [markdown]
# # Examine Categorical Summary Stats

# %%
categorical_stats = pd.DataFrame(columns = ['column', 'values', 'values_count_incna', 'values_count_nona', 
                                       'num_miss', 'pct_miss'])
tmp = pd.DataFrame()

for c in categorical_data.columns:
    tmp['column'] = [c]
    tmp['values'] = [categorical_data[c].unique()]
    tmp['values_count_incna'] = len(list(categorical_data[c].unique()))
    tmp['values_count_nona'] = int(categorical_data[c].nunique())
    tmp['num_miss'] = categorical_data[c].isnull().sum()
    tmp['pct_miss'] = (categorical_data[c].isnull().sum()/ len(categorical_data)).round(3)*100
    categorical_stats = categorical_stats.append(tmp)
    
categorical_stats
# Out:
#           column                                             values  \
# 0       MSZoning                          [RL, RM, C (all), FV, RH]
# 0         Street                                       [Pave, Grvl]
# 0          Alley                                  [nan, Grvl, Pave]
# 0       LotShape                               [Reg, IR1, IR2, IR3]
# 0    LandContour                               [Lvl, Bnk, Low, HLS]
# 0      Utilities                                   [AllPub, NoSeWa]
# 0      LotConfig                [Inside, FR2, Corner, CulDSac, FR3]
# 0      LandSlope                                    [Gtl, Mod, Sev]
# 0   Neighborhood  [CollgCr, Veenker, Crawfor, NoRidge, Mitchel, ...
# 0     Condition1  [Norm, Feedr, PosN, Artery, RRAe, RRNn, RRAn, ...
# 0     Condition2  [Norm, Artery, RRNn, Feedr, PosN, PosA, RRAn, ...
# 0       BldgType              [1Fam, 2fmCon, Duplex, TwnhsE, Twnhs]
# 0     HouseStyle  [2Story, 1Story, 1.5Fin, 1.5Unf, SFoyer, SLvl,...
# ...

# %%
# Let's do an Ascending sort on the Numboer of Distinct Categories for each categorical Variables
categorical_stats.sort_values(by = 'pct_miss', inplace = True, ascending = False)

# And set the index to Column Names
categorical_stats.set_index('column', inplace = True)
categorical_stats
# Out:
#                                                           values  \
# column
# PoolQC                                         [nan, Ex, Fa, Gd]
# MiscFeature                        [nan, Shed, Gar2, Othr, TenC]
# Alley                                          [nan, Grvl, Pave]
# Fence                            [nan, MnPrv, GdWo, GdPrv, MnWw]
# FireplaceQu                            [nan, TA, Gd, Fa, Ex, Po]
# GarageType     [Attchd, Detchd, BuiltIn, CarPort, nan, Basmen...
# GarageCond                             [TA, Fa, nan, Gd, Po, Ex]
# GarageQual                             [TA, Fa, Gd, nan, Ex, Po]
# GarageFinish                                [RFn, Unf, Fin, nan]
# BsmtFinType2                 [Unf, BLQ, nan, ALQ, Rec, LwQ, GLQ]
# BsmtExposure                               [No, Gd, Mn, Av, nan]
# BsmtFinType1                 [GLQ, ALQ, Unf, Rec, BLQ, nan, LwQ]
# BsmtQual                                   [Gd, TA, Ex, nan, Fa]
# ...

# %%
# Add Target Variable to categorical dataframe
categorical_data["SalePrice"] = data.loc[categorical_data.index, "SalePrice"].copy()

# examine 6 categorical variables against target variable
fig = plt.figure(figsize = (15,10))

ax1 = fig.add_subplot(2,3,1)
sns.countplot(data = categorical_data, x = 'MSZoning', ax=ax1)

ax2 = fig.add_subplot(2,3,2)
sns.countplot(data = categorical_data, x = 'LotShape', ax=ax2)

ax3 = fig.add_subplot(2,3,3)
sns.countplot(data = categorical_data, x = 'LotConfig', ax=ax3)

ax4 = fig.add_subplot(2,3,4)
sns.boxplot(data = categorical_data, x = 'MSZoning', y = 'SalePrice' , ax=ax4)
#sns.violinplot(data = categorical_data, x = 'MSZoning', y = 'SalePrice' , ax=ax4)
#sns.swarmplot(data = categorical_data, x = 'MSZoning', y='SalePrice', color = 'k', alpha = 0.4, ax=ax4  )

ax5 = fig.add_subplot(2,3,5)
sns.boxplot(data = categorical_data, x = 'LotShape', y = 'SalePrice', ax=ax5)
#sns.violinplot(data = categorical_data, x = 'LotShape', y = 'SalePrice', ax=ax5)
#sns.swarmplot(data = categorical_data, x = 'LotShape', y='SalePrice', color = 'k', alpha = 0.4, ax=ax5  )

ax6 = fig.add_subplot(2,3,6)
sns.boxplot(data = categorical_data, x = 'LotConfig', y = 'SalePrice', ax=ax6)

# %% [markdown]
# # Examine all categorical variables

# %%
ix = 1
fig = plt.figure(figsize = (15,10))
for c in list(categorical_data.columns):
    if ix <= 3:
        if c != 'SalePrice':
            ax1 = fig.add_subplot(2,3,ix)
            sns.countplot(data = categorical_data, x=c, ax = ax1)
            plt.xticks(rotation=45)
            ax2 = fig.add_subplot(2,3,ix+3)
            sns.boxplot(data=categorical_data, x=c, y='SalePrice', ax=ax2)
            plt.xticks(rotation=45)
            #sns.violinplot(data=categorical_data, x=c, y='SalePrice', ax=ax2)
            #sns.swarmplot(data = categorical_data, x=c, y ='SalePrice', color = 'k', alpha = 0.4, ax=ax2)
            
    ix = ix +1
    if ix == 4: 
        fig = plt.figure(figsize = (15,10))
        ix =1

# %% [markdown]
# # Replace null values with None where appropriate

# %%
# display categorical data with missing values
categorical_data.loc[:, categorical_data.isna().any() == True].head(5)
# Out:
#   Alley MasVnrType BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  \
# 0   NaN    BrkFace       Gd       TA           No          GLQ          Unf
# 1   NaN       None       Gd       TA           Gd          ALQ          Unf
# 2   NaN    BrkFace       Gd       TA           Mn          GLQ          Unf
# 3   NaN       None       TA       Gd           No          ALQ          Unf
# 4   NaN    BrkFace       Gd       TA           Av          GLQ          Unf
#
#   Electrical FireplaceQu GarageType GarageFinish GarageQual GarageCond PoolQC  \
# 0      SBrkr         NaN     Attchd          RFn         TA         TA    NaN
# 1      SBrkr          TA     Attchd          RFn         TA         TA    NaN
# 2      SBrkr          TA     Attchd          RFn         TA         TA    NaN
# 3      SBrkr          Gd     Detchd          Unf         TA         TA    NaN
# 4      SBrkr          TA     Attchd          RFn         TA         TA    NaN
#
#   Fence MiscFeature
# ...

# %%
# numerical data
numeric_data.loc[:, numeric_data.isna().any() == True].head(5)
# Out:
#    LotFrontage  MasVnrArea  GarageYrBlt
# 0         65.0       196.0       2003.0
# 1         80.0         0.0       1976.0
# 2         68.0       162.0       2001.0
# 3         60.0         0.0       1998.0
# 4         84.0       350.0       2000.0

# %%
# Alley: Type of alley access to property ->    NA   No alley access
categorical_data.Alley = categorical_data.Alley.fillna("None")
# MasVnrType: Masonry veneer type -> None None
categorical_data.MasVnrType = categorical_data.MasVnrType.fillna("None")
# BsmtQual: Evaluates the height of the basement -> NA   No Basement
categorical_data.BsmtQual = categorical_data.BsmtQual.fillna("None")
# BsmtCond: Evaluates the general condition of the basement -> NA   No Basement
categorical_data.BsmtCond = categorical_data.BsmtCond.fillna("None")
# BsmtExposure: Refers to walkout or garden level walls -> NA   No Basement
categorical_data.BsmtExposure = categorical_data.BsmtExposure.fillna("None")
# BsmtFinType1: Rating of basement finished area -> NA   No Basement
categorical_data.BsmtFinType1 = categorical_data.BsmtFinType1.fillna("None")
# BsmtFinType2: Rating of basement finished area (if multiple types) -> NA   No Basement
categorical_data.BsmtFinType2 = categorical_data.BsmtFinType2.fillna("None")
# FireplaceQu: Fireplace quality -> NA   No Fireplace
categorical_data.FireplaceQu = categorical_data.FireplaceQu.fillna("None")
# GarageType: Garage location -> NA   No Garage
categorical_data.GarageType = categorical_data.GarageType.fillna("None")
# GarageFinish: Interior finish of the garage -> NA   No Garage
categorical_data.GarageFinish = categorical_data.GarageFinish.fillna("None")
# GarageQual: Garage quality -> NA   No Garage
categorical_data.GarageQual = categorical_data.GarageQual.fillna("None")
# GarageCond: Garage condition -> NA   No Garage
categorical_data.GarageCond = categorical_data.GarageCond.fillna("None")
# PoolQC: Pool quality -> NA   No Pool
categorical_data.PoolQC = categorical_data.PoolQC.fillna("None")
# Fence: Fence quality -> NA   No Fence
categorical_data.Fence = categorical_data.Fence.fillna("None")
# MiscFeature: Miscellaneous feature not covered in other categories -> NA   None
categorical_data.MiscFeature = categorical_data.MiscFeature.fillna("None")

# %% [markdown]
# ### Re-examine data with missing values after None replacements

# %% [markdown]
# ##### Categorical Data

# %%
# display categorical data with missing values
missing_data_stats = pd.DataFrame(columns = ['column', 'nan_pct'])
temp = pd.DataFrame()

missing_columns = categorical_data.loc[:, categorical_data.isna().any() == True].columns
for col in missing_columns:
    temp['column'] = [col]
    temp['nan_pct'] = categorical_data[col].isna().mean()
    missing_data_stats = missing_data_stats.append(temp)
    
missing_data_stats
# Out:
#        column   nan_pct
# 0  Electrical  0.000685

# %% [markdown]
# ##### Numeric Data

# %%
# display numeric data with missing values
missing_data_stats = pd.DataFrame(columns = ['column', 'nan_pct'])
temp = pd.DataFrame()

missing_columns = numeric_data.loc[:, numeric_data.isna().any() == True].columns
type(missing_columns)
for col in missing_columns:
    temp["column"] = [col]
    temp["nan_pct"] = numeric_data[col].isna().mean()
    missing_data_stats = missing_data_stats.append(temp)
    
missing_data_stats
# Out:
#         column   nan_pct
# 0  LotFrontage  0.177397
# 0   MasVnrArea  0.005479
# 0  GarageYrBlt  0.055479

# %% [markdown]
# # Impute Missing Data

# %% [markdown]
# ### Numeric Data

# %%
# make copy to avoid changing original data
# NOTE: copy full dataset including training and test data to increase imputation accuracy
imputed_data = numeric_data.copy()

# make new columns indicating what will be imputed
cols_with_missing = (col for col in imputed_data.columns 
                                 if imputed_data[col].isnull().any())

for col in cols_with_missing:
    imputed_data[col + '_was_missing'] = imputed_data[col].isnull()
    
# Imputation
my_imputer = SimpleImputer()
# translate dataframe to numpy matrix for fit_transofrm method
#imputed_data = imputed_data.values
numeric_imputed_data_copy = pd.DataFrame(my_imputer.fit_transform(imputed_data))
numeric_imputed_data_copy.columns = imputed_data.columns

numeric_imputed_data = numeric_imputed_data_copy
numeric_imputed_data.loc[:,["LotFrontage", "LotFrontage_was_missing", "MasVnrArea", "MasVnrArea_was_missing"]].head(15)
# Out:
#     LotFrontage  LotFrontage_was_missing  MasVnrArea  MasVnrArea_was_missing
# 0     65.000000                      0.0       196.0                     0.0
# 1     80.000000                      0.0         0.0                     0.0
# 2     68.000000                      0.0       162.0                     0.0
# 3     60.000000                      0.0         0.0                     0.0
# 4     84.000000                      0.0       350.0                     0.0
# 5     85.000000                      0.0         0.0                     0.0
# 6     75.000000                      0.0       186.0                     0.0
# 7     70.049958                      1.0       240.0                     0.0
# 8     51.000000                      0.0         0.0                     0.0
# 9     50.000000                      0.0         0.0                     0.0
# 10    70.000000                      0.0         0.0                     0.0
# ...

# %% [markdown]
# ### Categorical Data

# %%
# import custom imputing class that handles categorical features
from SeriesImputer import SeriesImputer

# make copy to avoid changing original data
# NOTE: copy full dataset including training and test data to increase imputation accuracy
imputed_data = categorical_data.copy()

# make new columns indicating what will be imputed
cols_with_missing = [col for col in imputed_data.columns 
                                 if imputed_data[col].isnull().any()]

# replace missing values with most frequently occuring value
for col in cols_with_missing:
    imputer = SeriesImputer()
    imputer.fit(imputed_data[col])
    imputed_data[col + '_imputed'] = imputer.transform(imputed_data[col])

categroical_imputed_data = imputed_data
categroical_imputed_data.loc[categroical_imputed_data["Electrical"].isna() == True]
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 1379       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1        ...         GarageQual GarageCond  \
# 1379       Timber       Norm        ...                 TA         TA
#
#      PavedDrive PoolQC Fence MiscFeature SaleType SaleCondition SalePrice  \
# 1379          Y   None  None        None       WD        Normal    167500
#
#      Electrical_imputed
# 1379              SBrkr
#
# [1 rows x 45 columns]

# %% [markdown]
# # Remove NaN values above an 80% threshold

# %% [raw]
# # remove columns with a nan % threshold
# numeric_data = numeric_data.loc[:, numeric_data.isnull().mean() < .8]
#
# numeric_nan_pct = numeric_data.isna().mean()
# # only display columns with a nan% above zero
# print(numeric_nan_pct[numeric_nan_pct > 0])

# %% [raw]
# # remove columns with a nan % threshold
# categorical_data = categorical_data.loc[:, categorical_data.isnull().mean() < .8]
#
# categorical_nan_pct = categorical_data.isna().mean()
# # only display columns with a nan% above zero
# print(categorical_nan_pct[categorical_nan_pct > 0])

# %% [markdown]
# # Investigate Numeric Interpolation

# %% [raw]
# # interpolate numerical data
# sns.relplot(x = "LotFrontage", y="SalePrice", data=numeric_data)
#
# numeric_data["LotFrontage"] = numeric_data["LotFrontage"].interpolate(method="spline", order = 3)
# sns.relplot(x = "LotFrontage", y="SalePrice", data=numeric_data)

# %% [markdown]
# # Investigate Categorical Interpolation

# %% [raw]
# # convert column type object to column type category
# categorical_data["FireplaceQu"] = categorical_data["FireplaceQu"].astype("category")
# categorical_data.FireplaceQu.head()

# %% [raw]
# categorical_data.FireplaceQu.interpolate(method="spline", order=3)

# %% [raw]
# # Replace category values with numeric values and interpolate
# categorical_data.FireplaceQu = categorical_data["FireplaceQu"].cat.add_categories(-1).fillna(-1)
# categorical_data.FireplaceQu.head()
#
# # Examine data without NaN values
# #sns.catplot(x="FireplaceQu", data=categorical_data)

# %% [raw]
# # Examine data after Nan values replaced
# data.iloc[:, 57] = data.iloc[:, 57].interpolate(method='spline', order=3)
#
# #sns.stripplot(x="FireplaceQu", y="SalePrice", data=data)
#
# data.iloc[:, 57].head()

# %% [markdown]
# # Export Plots to PDF

# %% [raw]
# # Save all categorical plots to pdf file
# with PdfPages('categorical.pdf') as pdf_pages:
#     for i, col in enumerate(categorical_data.columns):
#         fig = plt.figure(i)
#         stripplot = sns.catplot(x=col, y="SalePrice", data=data)
#         plt.xticks(rotation=45)
#         pdf_pages.savefig(fig)
#         plt.close(fig)

# %% [raw]
# # Save all numerical plots to pdf file
# with PdfPages('numerical.pdf') as pdf_pages:
#     for i, col in enumerate(numeric_data.columns):
#         fig = plt.figure(i)
#         stripplot = sns.relplot(x=col, y="SalePrice", data=data)
#         plt.xticks(rotation=45)
#         pdf_pages.savefig(fig)
#         plt.close(fig)

# %% [markdown]
# # Examine P Values and Correlations of features

# %% [markdown]
# ##### Numeric Data

# %%
# examine correlation and p value of each numerical feature against sales price
pearson_correlations = {"column" : ["correlation", "p_value"]}
for i in numeric_imputed_data.columns:
	corr, p_value = pearsonr(numeric_imputed_data[i], data['SalePrice'])
	pearson_correlations[i] = [corr, p_value]

# convert dictionary to dataframe for export
pearson_correlations = pd.DataFrame.from_dict(pearson_correlations)
pearson_correlations.to_csv("~/Documents/Git/kaggle_housing_prices_advanced_regression_techniques/pearson_correlations.csv")

pearson_correlations
# Out:
#         column        Id  MSSubClass   LotFrontage       LotArea  \
# 0  correlation -0.021917   -0.084284  3.349009e-01  2.638434e-01
# 1      p_value  0.402694    0.001266  1.346651e-39  1.123139e-24
#
#      OverallQual  OverallCond      YearBuilt  YearRemodAdd    MasVnrArea  \
# 0   7.909816e-01    -0.077856   5.228973e-01  5.071010e-01  4.752413e-01
# 1  2.185675e-313     0.002912  2.990229e-103  3.164948e-96  3.924712e-83
#
#             ...             3SsnPorch  ScreenPorch  PoolArea   MiscVal  \
# 0           ...              0.044584     0.111447  0.092404 -0.021190
# 1           ...              0.088582     0.000020  0.000407  0.418486
#
#      MoSold    YrSold  SalePrice  LotFrontage_was_missing  \
# 0  0.046432 -0.028923        1.0                 0.004087
# 1  0.076128  0.269413        0.0                 0.876017
#
#    MasVnrArea_was_missing  GarageYrBlt_was_missing
# 0                0.051933            -2.368317e-01
# ...

# %% [markdown]
# ##### Categorical Data

# %%
## remove target variable SalesPRice from categorical data
categroical_imputed_data = categroical_imputed_data.drop(columns=["SalePrice"])
print(categroical_imputed_data.shape)
print(data.shape)

# examine correlation and p value of each categorical feature against sales price
spearman_correlations = {"column" : ["correlation", "p_value"]}
for i in categroical_imputed_data.columns:
    corr, p_value = spearmanr(categroical_imputed_data[i], data['SalePrice'])
    spearman_correlations[i] = [corr, p_value]
    
# convert dictionary to dataframe for export
spearman_correlations = pd.DataFrame.from_dict(spearman_correlations)
spearman_correlations.to_csv("~/Documents/Git/kaggle_housing_prices_advanced_regression_techniques/spearman_correlations.csv")

spearman_correlations
